# %%
#importing all library that are needed in project

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data (2).csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
sub_df=df[['sqft_living','sqft_lot']]
sub_df
# Out:
#       sqft_living  sqft_lot
# 0            1340      7912
# 1            3650      9050
# 2            1930     11947
# 3            2000      8030
# 4            1940     10500
# ...           ...       ...
# 4595         1510      6360
# 4596         1460      7573
# 4597         3010      7014
# 4598         2090      6630
# 4599         1490      8102
#
# [4600 rows x 2 columns]

# %%
sub_df.shape
# Out:
# (4600, 2)

# %%
sub_df.describe()
# Out:
#         sqft_living      sqft_lot
# count   4600.000000  4.600000e+03
# mean    2139.346957  1.485252e+04
# std      963.206916  3.588444e+04
# min      370.000000  6.380000e+02
# 25%     1460.000000  5.000750e+03
# 50%     1980.000000  7.683000e+03
# 75%     2620.000000  1.100125e+04
# max    13540.000000  1.074218e+06

# %%
sub_df.info
# Out:
# <bound method DataFrame.info of       sqft_living  sqft_lot
# 0            1340      7912
# 1            3650      9050
# 2            1930     11947
# 3            2000      8030
# 4            1940     10500
# ...           ...       ...
# 4595         1510      6360
# 4596         1460      7573
# 4597         3010      7014
# 4598         2090      6630
# 4599         1490      8102
#
# [4600 rows x 2 columns]>

# %%
plt.scatter(sub_df['sqft_living'],sub_df['sqft_lot'])
plt.xlabel('sqft_living')
plt.ylabel('sqft_lot')
# Out:
# Text(0, 0.5, 'sqft_lot')

# %%
sns.scatterplot(data=sub_df,x='sqft_living',y='sqft_lot')
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_lot'>

# %%
sns.lineplot(data =sub_df ,x='sqft_living',y='sqft_lot')
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_lot'>

# %%
sns.pairplot(sub_df)

# %%
#linear regression 
X = sub_df.iloc[:,0]
y = sub_df.iloc[:,1]

# %%
X
# Out:
# 0       1340
# 1       3650
# 2       1930
# 3       2000
# 4       1940
#         ...
# 4595    1510
# 4596    1460
# 4597    3010
# 4598    2090
# 4599    1490
# Name: sqft_living, Length: 4600, dtype: int64

# %%
y
# Out:
# 0        7912
# 1        9050
# 2       11947
# 3        8030
# 4       10500
#         ...
# 4595     6360
# 4596     7573
# 4597     7014
# 4598     6630
# 4599     8102
# Name: sqft_lot, Length: 4600, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y ,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X_test
# Out:
# 4111    1460
# 1996    1560
# 2307    2340
# 3607    1110
# 1519    2798
#         ...
# 2516    2960
# 993     1990
# 3713    1620
# 4541    2210
# 3016    2200
# Name: sqft_living, Length: 920, dtype: int64

# %%
y_test
# Out:
# 4111    15000
# 1996    31299
# 2307     6000
# 3607     1773
# 1519     4473
#         ...
# 2516    41656
# 993      6671
# 3713     9310
# 4541     4000
# 3016    20000
# Name: sqft_lot, Length: 920, dtype: int64

# %%
lr.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
lr.predict(np.array(X_test.iloc[0]).reshape(1,1))
# Out:
# array([10080.14969967])

# %%
#best fit line

plt.scatter(sub_df['sqft_living'],sub_df['sqft_lot'])
plt.plot(X_train,lr.predict(X_train.values.reshape(-1, 1)),color='red')
plt.xlabel('sqft_living')
plt.ylabel('sqft_lot')
# Out:
# Text(0, 0.5, 'sqft_lot')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 1460+ b
# Out:
# array([10080.14969967])

# %%
m * 15000 + b
# Out:
# array([108593.84188051])
